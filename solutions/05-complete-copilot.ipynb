# %% [markdown]
# # Lab 05 · The Complete Copilot
#
# So far each capability lived in its own agent:
#
# - **Lab 02** — installed-base tools (warranty, site, escalation)
# - **Lab 03/04** — manual knowledge (fault codes, specs, safety)
#
# A real field question needs **both** at once:
#
# > *"The Galaxy VS with serial GVS-0001 is throwing E07 — is it under warranty, and
# > what should I do?"*
#
# In this lab we give **one agent all the tools** and let it **orchestrate**: it
# decides which tool(s) to call, in what order, and combines the results into a
# single grounded answer. This is *single-agent tool orchestration* — the most
# common and robust production pattern.
#
# > 🧭 **Prerequisite:** run **Lab 04** first so the Azure AI Search index exists —
# > the manual-search tool queries it.
#
# > ⚠️ Synthetic training data — not affiliated with or endorsed by Schneider Electric.

# %% [markdown]
# ## 1. Assemble every capability
#
# We combine the three installed-base function tools with a `search_product_manuals`
# tool (which queries the Lab 04 index under the hood).

# %%
import sys, warnings
from pathlib import Path

warnings.filterwarnings("ignore")  # hide experimental-feature notices for a clean lab
here = Path.cwd()
src = next((p / "src" for p in [here, *here.parents] if (p / "src" / "config.py").exists()), None)
if src and str(src) not in sys.path:
    sys.path.insert(0, str(src))

import config

from tools import INSTALLED_BASE_TOOLS, search_product_manuals

ALL_TOOLS = INSTALLED_BASE_TOOLS + [search_product_manuals]
print("Copilot tools:", [t.__name__ for t in ALL_TOOLS])
# Out:
# Copilot tools: ['lookup_asset_by_serial', 'list_assets_for_site', 'check_warranty_and_contract', 'search_product_manuals']

# %% [markdown]
# ## 2. Build the orchestrating agent
#
# Same Agent Framework pattern as Lab 02 — we just hand it the full toolset and
# instructions on **when** to use each.

# %%
from agent_framework_foundry import FoundryChatClient
from azure.identity.aio import AzureCliCredential

COPILOT_INSTRUCTIONS = config.TECH_PERSONA + """

You are the complete field copilot. You have two kinds of tools:
- Installed-base tools (lookup_asset_by_serial, list_assets_for_site,
  check_warranty_and_contract) for questions about specific equipment, sites,
  warranty, and service contracts.
- search_product_manuals for fault codes, specifications, safety, and procedures.

For a technician's request, use WHICHEVER tools are needed — often both — and
combine the results into one clear, safety-first answer. Cite the manual sections
you rely on. If an asset is out of warranty with no contract, flag that it needs
escalation.
"""

async def ask_copilot(question):
    async with AzureCliCredential(process_timeout=30) as credential:
        client = FoundryChatClient(credential=credential)
        agent = client.as_agent(
            name="schneider-complete-copilot",
            instructions=COPILOT_INSTRUCTIONS,
            tools=ALL_TOOLS,
        )
        return await agent.run(question)

print("Copilot ready.")
# Out:
# Copilot ready.

# %% [markdown]
# ## 3. A question that needs both capabilities
#
# Watch the agent call **`lookup_asset_by_serial` / `check_warranty_and_contract`**
# *and* **`search_product_manuals`**, then merge warranty status with the E07
# procedure and safety guidance.

# %%
q = ("The Galaxy VS UPS with serial GVS-0001 is throwing fault code E07. "
     "Is it still under warranty, and what should the technician do about E07?")
print("👤", q, "\n")
print("🤖", await ask_copilot(q))
# Out:
# 👤 The Galaxy VS UPS with serial GVS-0001 is throwing fault code E07. Is it still under warranty, and what should the technician do about E07?
# 🤖 For **GVS-0001 (Galaxy VS)**:
#
# - **Warranty:** **Out of warranty**
# - **Warranty expiry:** **2023-12-31**
# - **Service contract:** **EcoStruxure Service Plan - Premium**
# - **Escalation flag:** **No** — it is out of warranty, but it does have active service coverage.
#
# For **fault code E07** on Galaxy VS:
#
# - **Meaning:** **DC bus overvoltage detected on the capacitor bank**
# - **First technician action:** **Transfer load to static bypass, isolate the UPS, then inspect the DC bus and rectifier IGBT stage before restart.**
#   **Source:** *Galaxy VS Uninterruptible Power Supply (UPS) · 3. Fault Codes*
#
# Safety first:
# - Apply **LOTO** before servicing.
# - Use **arc-flash PPE** if the cabinet is energized.
# - The **DC capacitor bank can retain lethal charge for up to 5 minutes after isolation** — verify **zero energy with a meter** before contact.
#   **Source:** *Galaxy VS Uninterruptible Power Supply (UPS) · 4. Safety*
#
# Recommended field sequence:
# 1. **Stabilize the load** — transfer to **static bypass** if conditions allow.
# 2. **Isolate the UPS** per site procedure.
# 3. Wait for discharge time and **verify DC bus is de-energized** with a meter.
# 4. Inspect:
#    - **DC bus/capacitor bank**
#    - **Rectifier IGBT stage**
#    - Any signs of swelling, leakage, discoloration, or damaged power components
# 5. Only attempt restart after the overvoltage cause is identified/corrected.
#
# Note: the fault-code guidance came from a **synthetic training manual** returned by the knowledge base, so treat it as the available reference for this exercise and verify against the official site documentation if required.
#
# If you want, I can also help you build a quick **on-site diagnostic checklist for E07**.

# %% [markdown]
# ## 4. Site triage + escalation
#
# A broader request: review a site and flag anything needing escalation.

# %%
q2 = ("I'm heading to site SITE-CHN-01. List the equipment there, and tell me which "
      "assets are out of warranty with no service contract so I can pre-authorize a "
      "chargeable visit.")
print("👤", q2, "\n")
print("🤖", await ask_copilot(q2))
# Out:
# 👤 I'm heading to site SITE-CHN-01. List the equipment there, and tell me which assets are out of warranty with no service contract so I can pre-authorize a chargeable visit.
# 🤖 Site **SITE-CHN-01 — Chennai Manufacturing Plant** has **5 installed assets**:
#
# - **GVS-0001** — Galaxy VS
#   - Installed: 2018-01-15
#   - Firmware baseline: v1.0
#   - Warranty: **Out of warranty**
#   - Service contract: **EcoStruxure Service Plan - Premium**
#
# - **MTZ-0001** — Masterpact MTZ
#   - Installed: 2021-04-15
#   - Firmware baseline: v1.3
#   - Warranty: **In warranty**
#   - Service contract: **None**
#
# - **ATV630-0002** — Altivar ATV630
#   - Installed: 2018-07-15
#   - Firmware baseline: v1.1
#   - Warranty: **Out of warranty**
#   - Service contract: **EcoStruxure Service Plan - Advantage**
#
# - **PM8K-0003** — PowerLogic PM8000
#   - Installed: 2021-01-15
#   - Firmware baseline: v1.4
#   - Warranty: **In warranty**
#   - Service contract: **EcoStruxure Service Plan - Preventive**
#
# - **GVS-0004** — Galaxy VS
#   - Installed: 2018-04-15
#   - Firmware baseline: v1.2
#   - Warranty: **Out of warranty**
#   - Service contract: **EcoStruxure Service Plan - Premium**
#
# **Assets out of warranty with no service contract:**
# - **None found**
#
# So based on the installed-base data, there are **no assets at this site that are both out of warranty and uncovered by service contract**. A blanket **chargeable pre-authorization is not indicated** from the current records.
#
# Safety reminder for site arrival: follow **LOTO**, verify absence of voltage, use appropriate **arc-flash PPE**, and treat UPS/DC bus equipment and drives as having **stored energy** until discharge is confirmed.

# %% [markdown]
# ## 5. Pure-knowledge question still works
#
# The same agent answers a manual-only question without touching the installed-base
# tools — orchestration means *using only what's needed*.

# %%
q3 = "On an ATV630, what does SCF3 indicate and how should I respond?"
print("👤", q3, "\n")
print("🤖", await ask_copilot(q3))
# Out:
# 👤 On an ATV630, what does SCF3 indicate and how should I respond?
# 🤖 On an **ATV630**, **SCF3** means **ground fault detected at the drive output**.
#
# **Recommended response:**
# 1. **Do not keep resetting it repeatedly.**
# 2. **De-energize the equipment** and follow **LOTO**.
# 3. Use appropriate **arc-flash PPE** if exposure exists while verifying status.
# 4. Remember the drive has **stored energy in the DC bus/capacitors** — wait the specified discharge time and **verify zero energy with a meter before contact**.
# 5. Inspect:
#    - **Motor windings** for insulation breakdown
#    - **Output cable** for damaged insulation, moisture, crushed jacket, or phase-to-ground leakage
#    - Motor terminal box and grounding condition
# 6. If needed, perform insulation testing on the **motor and motor leads** per site practice and Schneider procedure limits.
#
# **Most likely causes:**
# - Motor winding insulation failure
# - Damaged output cable
# - Grounded/contaminated motor terminals
# - Moisture ingress in motor or cable
#
# **Manual source:** *Altivar Process ATV630 Variable Speed Drive · 3. Fault Codes*
# - **SCF3 — “Ground fault detected at output”**
# - **First technician action:** “Inspect motor windings and output cabling for insulation breakdown; do not reset repeatedly.”
#
# If you want, I can also give you a **step-by-step field isolation plan** to determine whether the fault is in the **drive, cable, or motor**.

# %% [markdown]
# ## 🙌 Your turn
#
# 1. Ask a question that mixes **two products** at **two sites** (e.g. compare an
#    asset's warranty at one site with a fault-code procedure for another). See how
#    the agent chains multiple tool calls.
# 2. **Advanced:** true *multi-agent* systems route between separate specialist
#    agents (e.g. a dedicated "safety officer" agent). Sketch how you'd split this
#    copilot into a router + specialists, and what state each would need.

# %%
# 👉 Your experiment here.

# %% [markdown]
# ## Recap
#
# One agent, many tools, orchestrated automatically — this is your deployable
# Schneider Field Service Copilot. In **Lab 06** we prove it's trustworthy with
# **evaluations** and **observability**.
